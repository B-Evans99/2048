# %% [markdown]
# ## Graphing the variation evaluation round
#
# Let's begin by plotting the raw data.

# %%
import numpy as np
import pandas as pd
from math import floor
import matplotlib.pyplot as plt

control = pd.read_csv('./data/evaluate_variation.csv',names=["Best solution"])
control.round(0)
control.astype(int)
control.style.set_caption("Raw control evaluation")

ax = control.plot.line()
ax.set_title("Variaton evaluation round raw data")
ax.set_xlabel("Generation")
ax.set_ylabel("Best solution")
# Out:
# Text(0, 0.5, 'Best solution')

# %% [markdown]
# Just like the **control** evaluation round, this raw graph is very noisy. Let's smooth it out.

# %%
import numpy as np
import pandas as pd
from math import floor
import matplotlib.pyplot as plt

control = pd.read_csv('./data/evaluate_variation.csv',names=["Best solution"])
control.round(0)
control.astype(int)

raw = [floor(row[0]) for row in control.values]
smoothed = []
for (i,s) in enumerate(raw[10:]):
    smoothed.append(sum(raw[i:i+10])/10)

graph = pd.DataFrame({"Best solution": smoothed})
    
ax = graph.plot.line()
ax.set_title("Variation evaluation round data smoothed over 10 generations")
ax.set_xlabel("Generation")
ax.set_ylabel("Best solution")
# Out:
# Text(0, 0.5, 'Best solution')

# %% [markdown]
# Again, we see that the model will improve over this. This is still a very jagged graph, so let's smooth to the average value of the generation and the 49 preceding generations.

# %%
import numpy as np
import pandas as pd
from math import floor
import matplotlib.pyplot as plt

control = pd.read_csv('./data/evaluate_variation.csv',names=["Best solution"])
control.round(0)
control.astype(int)

raw = [floor(row[0]) for row in control.values]
smoothed = []
for (i,s) in enumerate(raw[50:]):
    smoothed.append(sum(raw[i:i+50])/50)

graph = pd.DataFrame({"Best solution": smoothed})

ax = graph.plot.line()
ax.set_title("Variation evaluation round data smoothed over 50 generations")
ax.set_xlabel("Generation")
ax.set_ylabel("Best solution")
# Out:
# Text(0, 0.5, 'Best solution')

# %% [markdown]
# We can now clearly see that the individuals are becoming more skilled, even if generations may not perform well due to randomness. Here, we can see the beginning of behavior that will become important: drops in skill which are followed by new skill peaks.
#
# Let's begin the [control experiment round](control.ipynb).
